# %% [markdown]
# <img src='img8/1.jpg' width='60%' />

# %% [markdown]
# # 8.1  数字图像概述
# ## 8.1.1  数字图像
# 数字图像
#
#     • 将图像进行数字化
#     • 使用给定大小的网格将连续图像离散化
#     • 每个小方格（像素）被记录为一种颜色
#     • 颜色矩阵表示数字图像
# <img src='img8/3.jpg' width='90%' />
#
# • 像素（Pixel）
#
#     • 数字图像的最小单位
#     • 每个像素具有横和纵位置坐标，以及颜色值
#     像素也被用来表示整幅图像的网格数，如某个固定大小的图像，像素越大越清晰
# <img src='img8/2.jpg' width='90%' />
#
# ## 8.1.2  数字图像类型
#
# 二值图像
#
#     • 像素矩阵由0、1两个值构成，
#     • “0”代表黑色，“1”代白色，用1位二进制表示
#
# 灰度图像
#
#     • 灰度图像矩阵元素的取值范围通常为[0，255]
#     • “0”表示纯黑色，“255”表示纯白色，中间的数字从小到大表示由黑到白的过渡色
#     • 用8位二进制表示
#     • 二值图像可以看成是灰度图像的特例
# <img src='img8/4.png' width='50%' />
# <img src='img8/5.jpg' width='30%' />
#
# RGB彩色图像
#
#     • 每个像素的颜色表示为：红（R）、绿（G）和蓝（B）三个基色分量
#     • 图像用3个M×N的二维矩阵
#     • 每个矩阵分别存放一个颜色分量，取值范围在[0，255]，表示该原色在该像素的深浅程度
#     • 每个像素的颜色使用3×8bit表示，也被称为24位图。
#
#  二值图像：只有黑和白，表现在像素上就是只有0和255。
#  灰度图像：有不同深度的灰色和黑白两色。
#  彩色图像：RGB图像，有255 * 255 * 255种颜色。
#
# 以上三种图像的区别可参考下面链接：https://blog.csdn.net/gaoxueyi551/article/details/112684581
# https://cloud.tencent.com/developer/article/1747172
#
#
# ## 8.1.3  数字图像处理
#
# • 图像变换（Geometrical Image Processing）
#
#     • 几何变换:坐标变换，图像的放大、缩小、旋转、移动，多个图像配准，全景畸变校正，扭曲校正，周长、面积、体积计算等
#     • 空间变换
#     • 傅里叶变换、离散余弦变换，小波缓缓将图像从时域变换到频域
#
# • 图像增强和复原（Image Enhancement & Restoration）
#
#     • 目的：提高图像的质量
#     • 方法：去除噪声，提高图像的清晰度
#
# • 图像重建（Image Reconstruction）
#
#     • 通过物体外部测量的数据经数字化处理获得物体的三维形状信息
#     • 投影重建、明暗恢复形状、立体视觉重建和激光测距重建
#
# • 图像编码（Image Encoding）
#
#     • 利用图像的统计特性、人类视觉生理学及心理学特性对图像数据进行编码
#     • 以较少的比特数表示图像或图像中所包含的信息
#     • 常见有JPEG、TIFF等压缩格式
#
# 图像识别（Image Recognition）
#
#     • 利用计算机对图像进行处理、分析和理解，识别各种不同模式的目标和对象空间变换
#     • 广泛地应用于导航、地图与地形配准、自然资源分析、天气预报、环境监测、生理病变研究等领域。

# %% [markdown]
# # 8.2  Python图像处理
# ## 8.2.1  Python图像处理库
# <img src='img8/6.jpg' width='80%' />
#
# ## 8.2.2  图像基本操作
# ### 8.2.2.1 图像的读取和显示
#
# 图像读取和显示
#
#     • 用ndarray的多维数组表示图像
#     • Scikit-image库的io库实现图片输入输出

# %%
from skimage import io
robot = io.imread('data/Robot.jpg')
print(robot.shape) #  图像像素和颜色字节数
print(type(robot)) # 数据类型
io.imshow(robot)
io.show()
# Out:
# (372, 400, 3)
# <class 'numpy.ndarray'>

# %% [markdown]
# ### 8.2.2.2 图像的坐标和颜色
# <img src='img8/8.png' width='60%' />

# %%
print(robot[21, 30]) # 取指定坐标像素的颜色

print(robot[21,30,0]) # 取指定坐标像素的R值，R用0代表
print(robot[21,30,1]) # 取指定坐标像素的G值，G用1代表
print(robot[21,30,2]) # 取指定坐标像素的B值，B用2代表

print(robot[0:21, 0:30, 0]) # 利用切片操作取一部分图像的R值
# Out:
# [ 76 114 137]
# 76
# 114
# 137
# [[76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
#   76 76 76 76 76 76]
#  [76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76 76
# ...

# %% [markdown]
# ### 8.2.2.3 图像裁剪
# 提取像素后可保存为图像

# %%
head = robot[40:170, 180:305] # 给出图像局部 head的坐标范围
io.imshow(head)
io.show()
io.imsave('RH.jpg', head) # 将图像数据保存为文件

# %% [markdown]
# # 8.3  案例：深度学习实现图像分类
#  图像分类的步骤：
#  - 对图像进行预处理，将图片中可能包含识别目标的矩阵分割出来
#  - 特征提取
#  - 基于图像特征训练分类器进行分类
#
#
# 前馈神经网络
#
#     • 全连接
# 图像数据非常大
#
#     • 1000×1000像素的灰度图像
#     • 输入层有1000×1000=100万个节点
#     • 第一个隐层有1000个节点
#     • 有1000×1000×1000=1亿个权重参数需要学习
# <img src='img8/7.jpg' width='60%' />
#
# ## 8.3.1  卷积神经网络
#
# keras中文官网链接：https://keras.io/zh/layers/convolutional/#conv2d
#
# 图像每个像素与周围像素关联紧密，与离得远的像素之间关联很小
#
# • CNN网络引入特定隐藏层，减少网络参数
# - CNN模型由卷积层和池化层组成卷积快，实现局部特征的提取
#
# • 卷积层（Conventional Layer）
#
#     • 由若干卷积单元组成
#     • 每个卷积单元仅仅连接输入单元的一部分
#     • 一组连接可以共享同一个权重
# <img src='img8/11.jpg' width='60%' />
# 卷积层官网链接：https://keras.io/zh/layers/convolutional/#conv2d
# <img src='img8/13.jpg' width='80%' />
# <img src='img8/6_2.jpg' width='60%' />
#
#
# • 池化层（Pooling layer）
#
#     • 将卷积后的特征切成几个区域，取其最大值或平均值
#     • 得到新的、维度较小的特征，从而减少隐层结点数。
# 池化层官网链接：https://keras.io/zh/layers/pooling/
# <img src='img8/6_1.jpg' width='60%' />
#
# • 全连接层（Fully-connected layer）
#
#     • 通过全连接层把所有局部特征结合变成全局特征，输出识别或分类结果。
# <img src='img8/12.jpg' width='60%' />
#
# 全连接层官网链接：https://keras.io/zh/layers/core/
#
# 了解概念可参考文章：https://www.cnblogs.com/boostwei/p/15195643.html
#
# 深入了解可学习：（相见恨晚的李宏毅老师）https://www.bilibili.com/video/BV1Wv411h7kN?p=31
#
# 以下是视频的文字版笔记：https://unclestrong.github.io/DeepLearning_LHY21_Notes/Notes_html/09_CNN.html
#
# <img src='img8/10.jpg' width='60%' />
#
# ## 8.3.2  基于Keras实现图像分类
# ### 8.3.2.1 图像数据集CIFAR-10
#
#  包括6万张32×32的 RGB 彩色图像图片
#
# • 被分成10类
#
# • 5万张图片用于训练，1万张图片用于测试。
#
# <img src='img8/9.jpg' width='70%' />

# %% [markdown]
# ### 8.3.2.2 图像分类的实现
# 需要安装keras
#
# pip install keras==2.6.0
#
# pip install tensorflow==2.6.0
#
# 除需要基本的神经网络层之外，还需要以下几层：
#  - 卷积层Conv2D: 二维卷积层，对二维输入进行滑动窗卷积。
#  - 池化层MaxPooling2D和AveragePooling2D：用于为每个区域实施最大值和平均值池化。
#  - Flatten层：用于将输入压平，即把多维的输入一维化，常用在从卷积层到全连接层的过渡。

# %% [markdown]
# 例8-1：构建CNN深度神经网络，基于CIFAR-10训练图像分类器

# %% [markdown]
# (1) 导入CIFAR-10数据集，分别获得训练集和测试集

# %%
from keras.datasets import cifar10
# 加载数据，划分测试集和训练集
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# 输出训练集和测试集的形状
print(x_train.shape, x_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3)

# %%
from matplotlib import pyplot
# 输出多个子图

for i in range(9):
    pyplot.subplot(331 + i)
    pyplot.imshow(x_train[i])
pyplot.show()

# %% [markdown]
# （2）对数据进行预处理，将像素值归一化为[0,1],多分类问题将分类标签转化为二元类矩阵

# %%
import numpy as np
from tensorflow.keras import utils
from tensorflow.keras.utils import to_categorical

num_classes = 10 # 分类个数
# 转换数据类型
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# 进行归一化处理，因为像素值都是从0-255的
x_train /= 255
x_test /= 255
# 为了将 整数目标值 转换为 分类目标值
# 对每个样本的类元素使用独热编码，将整数转换为10个元素的二进制向量，类值的索引为1。
# 把多分类问题转换成二分类问题
y_train = utils.to_categorical(y_train, num_classes)
y_test = utils.to_categorical(y_test, num_classes)

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# <img src='img8/13.gif' width='20%' />

# %% [markdown]
# （3）构建CNN模型

# %%
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Sequential

# 定义顺序模型
model = Sequential()

#第一个卷积块
# 32个3*3卷积核，步长为1，第一个网络层，需要有输入参数告诉神经网络输入的大小是多少
# same表示一种补0策略，填充前后图片大小不变
model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:]))

# 添加relu激活函数
model.add(Activation('relu'))

# 32个3*3卷积核
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))

# 池化层
model.add(MaxPooling2D(pool_size=(2, 2)))

# 防止过拟合
model.add(Dropout(0.25))

#第二个卷积块
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# 全连接层
# flatten 函数，将图像矩阵展平成一维的向量
model.add(Flatten())

# Dense层 全连接层 512代表该层的输出维度
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# 最后的Dense层 即全连接层， 输出所有的类别
model.add(Dense(num_classes))

# softmax输出分别属于哪类的概率
model.add(Activation('softmax'))

# %%
model.summary() #输出模型各层的参数状况
# (samples, rows, cols, channels)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  activation_1 (Activation)   (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  activation_2 (Activation)   (None, 15, 15, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
# ...

# %% [markdown]
# （4）对构建好的模型进行编译。这是多分类问题，损失函数选择categorical_crossentrogy，优化器选择RMSprop

# %%
from tensorflow import keras
import tensorflow as tf
from keras import optimizers

# 初始化RMSprop优化器
# 参考文档https://keras123.com/optimizers/

opt = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0001,decay=1e-6) # 每次参数更新后学习率衰减值。

# 模型编译
# https://keras.io/zh/losses/
# https://keras.io/zh/models/model/#compile
model.compile(loss='categorical_crossentropy', # loss函数，优化目标（多分类常用交叉熵函数）
              optimizer=opt, # 优化器
              metrics=['accuracy']) # 评价函数用于评估当前训练模型的性能

# %% [markdown]
# （5）训练CNN模型

# %%
# https://keras.io/zh/models/model/#compile
# 批处理,一次训练所抓取的数据样本数量，然后更新权值，减少计算量；
batch_size = 32

# 参数学习算法的迭代次数
epochs = 10
history = model.fit(x_train, y_train, 
          batch_size=batch_size, 
          epochs=epochs,
          validation_data=(x_test, y_test), 
          shuffle=True) # 是否在每轮迭代之前混洗数据,为了避免数据投入的顺序对网络训练造成影响。
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 155s 98ms/step - loss: 1.8203 - accuracy: 0.3337 - val_loss: 1.5611 - val_accuracy: 0.4469
# Epoch 2/10
# 1563/1563 [==============================] - 145s 93ms/step - loss: 1.4988 - accuracy: 0.4565 - val_loss: 1.3680 - val_accuracy: 0.5131
# Epoch 3/10
# 1563/1563 [==============================] - 148s 94ms/step - loss: 1.3528 - accuracy: 0.5159 - val_loss: 1.2330 - val_accuracy: 0.5573
# Epoch 4/10
# 1563/1563 [==============================] - 145s 93ms/step - loss: 1.2549 - accuracy: 0.5537 - val_loss: 1.1933 - val_accuracy: 0.5789
# Epoch 5/10
# 1563/1563 [==============================] - 160s 102ms/step - loss: 1.1762 - accuracy: 0.5837 - val_loss: 1.0893 - val_accuracy: 0.6144
# Epoch 6/10
# 1563/1563 [==============================] - 167s 107ms/step - loss: 1.1107 - accuracy: 0.6040 - val_loss: 1.0264 - val_accuracy: 0.6368
# Epoch 7/10
# ...

# %% [markdown]
# （6）保存获得的分类模型

# %%
model.save('B2CNN.h5')
del model

# %% [markdown]
# （7）对CNN模型进行性能评估

# %%
from keras.models import load_model
model = load_model('B2CNN.h5')
# 在测试模式下返回模型的误差值和评估标准值。
# https://keras.io/zh/models/model/#compile
scores = model.evaluate(x_test, y_test, 
                        verbose=0)#  0 或 1。日志显示模式。 0 = 安静模式，1 = 进度条。
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 0.8869084715843201
# Test accuracy: 0.690500020980835

# %% [markdown]
# （8）绘制loss曲线和精度曲线

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

import matplotlib
import matplotlib.pyplot as plt
 
plt.title('Accuracy and Loss')
plt.plot(epochs, acc, 'red', label='Training accuracy')
plt.plot(epochs, val_loss, 'blue', label='Validation loss')
plt.plot(epochs, val_acc, 'green', label='Validation accuracy')
plt.plot(epochs, loss, 'yellow', label='Training loss')
plt.legend()
plt.show()

# %% [markdown]
# # 8.3.2.3 使用预训练模型对图像进行分类

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet50 import decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

#导入预训练模型ResNet50
model = ResNet50(weights='imagenet') 
# weights: None 代表随机初始化
# 'imagenet' 代表加载在 ImageNet 上预训练的权值

# %%
# 对输入图片进行处理
img_path = 'data/elephant.jpg'
# 加载图片，保存在img_path路径下
#  target_size=(224, 224)表示输入的图像尺寸为（224，224），即一幅图像是一个224x224大小的二维数组
img = image.load_img(img_path, target_size=(224, 224))

X = image.img_to_array(img) # 将图像转换为数组
print(X)
print(X.shape)

# expand_dims用来扩展数组维度的，axis=0表示在0的位置加1维
#一般神经网络定义好都是四个维度，所以我们需要再添加一维
X = np.expand_dims(X, axis=0)

print(X.shape)

# 对样本执行逐样本均值消减 的归一化，去均值中心化，将图像足够适合模型所需的格式
X = preprocess_input(X)

# 模型预测
preds = model.predict(X)

print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# [[[154. 181. 202.]
#   [157. 184. 205.]
#   [160. 187. 208.]
#   ...
#   [169. 192. 210.]
#   [169. 192. 210.]
#   [168. 191. 209.]]
#
#  [[155. 182. 203.]
#   [158. 185. 206.]
#   [160. 187. 208.]
#   ...
#   [171. 194. 212.]
#   [171. 194. 212.]
#   [172. 195. 213.]]
#
#  [[157. 184. 205.]
#   [159. 186. 207.]
#   [161. 188. 209.]
#   ...
#   [173. 196. 214.]
#   [173. 196. 214.]
#   [175. 198. 216.]]
#
#  ...
#
#  [[158. 147.  67.]
#   [182. 168.  93.]
#   [230. 215. 146.]
#   ...
#   [163. 132.  86.]
#   [174. 146.  99.]
#   [153. 125.  78.]]
#
#  [[186. 175.  95.]
#   [207. 193. 118.]
#   [189. 171. 105.]
#   ...
#   [127.  96.  52.]
#   [128.  97.  51.]
#   [138. 107.  61.]]
#
#  [[145. 134.  55.]
#   [132. 120.  46.]
#   [148. 130.  66.]
#   ...
#   [147. 116.  72.]
#   [128.  97.  51.]
#   [136. 105.  58.]]]
# (224, 224, 3)
# (1, 224, 224, 3)
# 1/1 [==============================] - 1s 1s/step
# ...
