# %% [markdown]
# # 波士顿房价预测任务
#
# 波士顿房价预测是一个经典的机器学习任务，类似于程序员世界的“Hello World”。和大家对房价的普遍认知相同，波士顿地区的房价是由诸多因素影响的。该数据集统计了13种可能影响房价的因素和该类型房屋的均价，期望构建一个基于13个因素进行房价预测的模型，如 **图1** 所示。
# <br></br>
# <center><img src="https://ai-studio-static-online.cdn.bcebos.com/c19602ce74284e3b9a50422f8dc37c0c1c79cf5cd8424994b6a6b073dcb7c057" width="500" hegiht="" ></center>
# <center><br>图1：波士顿房价影响因素示意图</br></center>
# <br></br>
#
# 对于预测问题，可以根据预测输出的类型是连续的实数值，还是离散的标签，区分为回归任务和分类任务。因为房价是一个连续值，所以房价预测显然是一个回归任务。下面我们尝试用最简单的线性回归模型解决这个问题，并用神经网络来实现这个模型。
#
# ## 线性回归模型
#
# 假设房价和各影响因素之间能够用线性关系来描述：
#
# $$y = {\sum_{j=1}^Mx_j w_j} + b$$
#
# 模型的求解即是通过数据拟合出每个$w_j$和$b$。其中，$w_j$和$b$分别表示该线性模型的权重和偏置。一维情况下，$w_j$ 和 $b$ 是直线的斜率和截距。
#
# 线性回归模型使用均方误差作为损失函数（Loss），用以衡量预测房价和真实房价的差异，公式如下：
#
# $$MSE = \frac{1}{n} \sum_{i=1}^n(\hat{Y_i} - {Y_i})^{2}$$

# %% [markdown]
# 五个步骤：
# 1、数据处理：
# 从本地文件或网络地址读取数据，并做预处理操作，如校验数据的正确性等。
# 2、模型设计：
# 完成网络结构的设计（模型三要素之一），相当于模型的假设空间，即模型能够表达的关系集合。
# 3、训练配置：
# 设定模型采用的寻解算法（模型三要素之二），即优化器，并指定计算资源。
# 4、训练过程：
# 循环调用训练过程，每轮均包括前向计算、损失函数（优化目标，模型三要素之三）和后向传播这三个步骤。
# 5、保存模型：
# 将训练好的模型保存，以备预测时调用。

# %% [markdown]
# 1、数据处理：
# 从本地文件或网络地址读取数据，并做预处理操作，如校验数据的正确性等。

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def load_data():
    # 从文件导入数据
    datafile = './work/housing.data'
    data = np.fromfile(datafile, sep=' ')

    # 每条数据包括14项，其中前面13项是影响因素，第14项是相应的房屋价格中位数
    feature_names = [ 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', \
                      'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV' ]
    feature_num = len(feature_names)

    # 将原始数据进行Reshape，变成[N, 14]这样的形状
    data = data.reshape([data.shape[0] // feature_num, feature_num])

    # 将原数据集拆分成训练集和测试集
    # 这里使用80%的数据做训练，20%的数据做测试
    # 测试集和训练集必须是没有交集的
    ratio = 0.8
    offset = int(data.shape[0] * ratio)
    training_data = data[:offset]

    # 计算train数据集的最大值，最小值，平均值
    maximums, minimums, avgs = training_data.max(axis=0), training_data.min(axis=0), \
                                 training_data.sum(axis=0) / training_data.shape[0]

    # 对数据进行归一化处理
    for i in range(feature_num):
        #print(maximums[i], minimums[i], avgs[i])
        data[:, i] = (data[:, i] - avgs[i]) / (maximums[i] - minimums[i])

    # 训练集和测试集的划分比例
    training_data = data[:offset]
    test_data = data[offset:]
    return training_data, test_data

# end load_data

# %% [markdown]
# 2、模型设计：
# 完成网络结构的设计（模型三要素之一），相当于模型的假设空间，即模型能够表达的关系集合。
#
# 3、训练配置：
# 设定模型采用的寻解算法（模型三要素之二），即优化器，并指定计算资源。
#
# 4、训练过程：
# 循环调用训练过程，每轮均包括前向计算、损失函数（优化目标，模型三要素之三）和后向传播这三个步骤。

# %%
class Network(object):
    def __init__(self, num_of_weights):
        # 随机产生w的初始值
        # 为了保持程序每次运行结果的一致性，此处设置固定的随机数种子
        np.random.seed(0)
        self.w = np.random.randn(num_of_weights, 1)
        self.b = 0.
        
    def forward(self, x):
        z = np.dot(x, self.w) + self.b
        return z
    
    def loss(self, z, y):
        error = z - y
        num_samples = error.shape[0]
        cost = error * error
        cost = np.sum(cost) / num_samples
        return cost
    
    def gradient(self, x, y):
        z = self.forward(x)
        N = x.shape[0]
        gradient_w = 1. / N * np.sum((z-y) * x, axis=0)
        gradient_w = gradient_w[:, np.newaxis]
        gradient_b = 1. / N * np.sum(z-y)
        return gradient_w, gradient_b
    
    def update(self, gradient_w, gradient_b, eta = 0.01):
        self.w = self.w - eta * gradient_w
        self.b = self.b - eta * gradient_b
            
                
    def train(self, training_data, num_epoches, batch_size=10, eta=0.01):
        n = len(training_data)
        losses = []
        for epoch_id in range(num_epoches):
            # 在每轮迭代开始之前，将训练数据的顺序随机的打乱，
            # 然后再按每次取batch_size条数据的方式取出
            np.random.shuffle(training_data)
            # 将训练数据进行拆分，每个mini_batch包含batch_size条的数据
            mini_batches = [training_data[k:k+batch_size] for k in range(0, n, batch_size)]
            for iter_id, mini_batch in enumerate(mini_batches):
                #print(self.w.shape)
                #print(self.b)
                x = mini_batch[:, :-1]
                y = mini_batch[:, -1:]
                a = self.forward(x)
                loss = self.loss(a, y)
                gradient_w, gradient_b = self.gradient(x, y)
                self.update(gradient_w, gradient_b, eta)
                losses.append(loss)
                print('Epoch {:3d} / iter {:3d}, loss = {:.4f}'.
                                 format(epoch_id, iter_id, loss))
        
        return losses

# end class

# %%
# 获取数据
train_data, test_data = load_data()

# 创建网络
net = Network(13)
# 启动训练
losses = net.train(train_data, num_epoches=100, batch_size=101, eta=0.1)
# Out:
# Epoch   0 / iter   0, loss = 2.4478
# Epoch   0 / iter   1, loss = 1.5378
# Epoch   0 / iter   2, loss = 1.5567
# Epoch   0 / iter   3, loss = 1.8429
# Epoch   1 / iter   0, loss = 1.9908
# Epoch   1 / iter   1, loss = 1.5147
# Epoch   1 / iter   2, loss = 1.1783
# Epoch   1 / iter   3, loss = 1.3318
# Epoch   2 / iter   0, loss = 1.1110
# Epoch   2 / iter   1, loss = 1.2320
# Epoch   2 / iter   2, loss = 1.2967
# Epoch   2 / iter   3, loss = 1.3114
# Epoch   3 / iter   0, loss = 0.8575
# Epoch   3 / iter   1, loss = 1.2703
# Epoch   3 / iter   2, loss = 0.9128
# Epoch   3 / iter   3, loss = 1.0778
# Epoch   4 / iter   0, loss = 1.1601
# Epoch   4 / iter   1, loss = 0.8753
# Epoch   4 / iter   2, loss = 0.7271
# Epoch   4 / iter   3, loss = 0.7025
# Epoch   5 / iter   0, loss = 1.1135
# Epoch   5 / iter   1, loss = 0.6898
# Epoch   5 / iter   2, loss = 0.6574
# Epoch   5 / iter   3, loss = 0.4934
# Epoch   6 / iter   0, loss = 0.5938
# Epoch   6 / iter   1, loss = 0.6151
# Epoch   6 / iter   2, loss = 0.6484
# Epoch   6 / iter   3, loss = 0.6847
# Epoch   7 / iter   0, loss = 0.5953
# Epoch   7 / iter   1, loss = 0.4635
# Epoch   7 / iter   2, loss = 0.7372
# Epoch   7 / iter   3, loss = 0.4225
# Epoch   8 / iter   0, loss = 0.5901
# Epoch   8 / iter   1, loss = 0.4476
# Epoch   8 / iter   2, loss = 0.6353
# Epoch   8 / iter   3, loss = 0.2888
# Epoch   9 / iter   0, loss = 0.4764
# Epoch   9 / iter   1, loss = 0.4610
# Epoch   9 / iter   2, loss = 0.3402
# Epoch   9 / iter   3, loss = 0.4737
# Epoch  10 / iter   0, loss = 0.4991
# Epoch  10 / iter   1, loss = 0.2761
# Epoch  10 / iter   2, loss = 0.4967
# Epoch  10 / iter   3, loss = 0.3125
# Epoch  11 / iter   0, loss = 0.3978
# Epoch  11 / iter   1, loss = 0.3855
# Epoch  11 / iter   2, loss = 0.2943
# Epoch  11 / iter   3, loss = 0.3676
# Epoch  12 / iter   0, loss = 0.3156
# Epoch  12 / iter   1, loss = 0.2605
# Epoch  12 / iter   2, loss = 0.2955
# Epoch  12 / iter   3, loss = 0.4602
# Epoch  13 / iter   0, loss = 0.4136
# Epoch  13 / iter   1, loss = 0.2205
# Epoch  13 / iter   2, loss = 0.4007
# Epoch  13 / iter   3, loss = 0.2044
# Epoch  14 / iter   0, loss = 0.2835
# Epoch  14 / iter   1, loss = 0.3193
# Epoch  14 / iter   2, loss = 0.2721
# Epoch  14 / iter   3, loss = 0.2823
# Epoch  15 / iter   0, loss = 0.2160
# Epoch  15 / iter   1, loss = 0.3499
# Epoch  15 / iter   2, loss = 0.2951
# Epoch  15 / iter   3, loss = 0.2287
# Epoch  16 / iter   0, loss = 0.2416
# Epoch  16 / iter   1, loss = 0.2195
# Epoch  16 / iter   2, loss = 0.2879
# Epoch  16 / iter   3, loss = 0.2810
# Epoch  17 / iter   0, loss = 0.2803
# Epoch  17 / iter   1, loss = 0.2356
# Epoch  17 / iter   2, loss = 0.2236
# Epoch  17 / iter   3, loss = 0.2399
# Epoch  18 / iter   0, loss = 0.1900
# Epoch  18 / iter   1, loss = 0.2511
# Epoch  18 / iter   2, loss = 0.1500
# Epoch  18 / iter   3, loss = 0.3436
# Epoch  19 / iter   0, loss = 0.1951
# Epoch  19 / iter   1, loss = 0.2944
# Epoch  19 / iter   2, loss = 0.1318
# Epoch  19 / iter   3, loss = 0.2744
# Epoch  20 / iter   0, loss = 0.1905
# Epoch  20 / iter   1, loss = 0.2414
# Epoch  20 / iter   2, loss = 0.2193
# Epoch  20 / iter   3, loss = 0.2078
# Epoch  21 / iter   0, loss = 0.2646
# Epoch  21 / iter   1, loss = 0.2087
# Epoch  21 / iter   2, loss = 0.1629
# Epoch  21 / iter   3, loss = 0.1911
# Epoch  22 / iter   0, loss = 0.2132
# Epoch  22 / iter   1, loss = 0.2278
# Epoch  22 / iter   2, loss = 0.1738
# Epoch  22 / iter   3, loss = 0.1825
# Epoch  23 / iter   0, loss = 0.1226
# Epoch  23 / iter   1, loss = 0.2457
# Epoch  23 / iter   2, loss = 0.2708
# Epoch  23 / iter   3, loss = 0.1313
# Epoch  24 / iter   0, loss = 0.2097
# Epoch  24 / iter   1, loss = 0.1695
# Epoch  24 / iter   2, loss = 0.1632
# Epoch  24 / iter   3, loss = 0.2021
# Epoch  25 / iter   0, loss = 0.1650
# Epoch  25 / iter   1, loss = 0.2146
# Epoch  25 / iter   2, loss = 0.1759
# Epoch  25 / iter   3, loss = 0.1658
# Epoch  26 / iter   0, loss = 0.2278
# Epoch  26 / iter   1, loss = 0.1531
# Epoch  26 / iter   2, loss = 0.1820
# Epoch  26 / iter   3, loss = 0.1389
# Epoch  27 / iter   0, loss = 0.1809
# Epoch  27 / iter   1, loss = 0.1679
# Epoch  27 / iter   2, loss = 0.1858
# Epoch  27 / iter   3, loss = 0.1455
# Epoch  28 / iter   0, loss = 0.1290
# Epoch  28 / iter   1, loss = 0.1441
# Epoch  28 / iter   2, loss = 0.1991
# Epoch  28 / iter   3, loss = 0.1880
# Epoch  29 / iter   0, loss = 0.2060
# Epoch  29 / iter   1, loss = 0.1664
# Epoch  29 / iter   2, loss = 0.1365
# Epoch  29 / iter   3, loss = 0.1335
# Epoch  30 / iter   0, loss = 0.1449
# Epoch  30 / iter   1, loss = 0.1615
# Epoch  30 / iter   2, loss = 0.1963
# Epoch  30 / iter   3, loss = 0.1228
# Epoch  31 / iter   0, loss = 0.1641
# Epoch  31 / iter   1, loss = 0.1493
# Epoch  31 / iter   2, loss = 0.1060
# Epoch  31 / iter   3, loss = 0.1886
# Epoch  32 / iter   0, loss = 0.1998
# Epoch  32 / iter   1, loss = 0.1674
# Epoch  32 / iter   2, loss = 0.1195
# Epoch  32 / iter   3, loss = 0.1058
# Epoch  33 / iter   0, loss = 0.1616
# Epoch  33 / iter   1, loss = 0.1107
# Epoch  33 / iter   2, loss = 0.1745
# Epoch  33 / iter   3, loss = 0.1312
# Epoch  34 / iter   0, loss = 0.1618
# Epoch  34 / iter   1, loss = 0.0967
# Epoch  34 / iter   2, loss = 0.1150
# Epoch  34 / iter   3, loss = 0.1905
# Epoch  35 / iter   0, loss = 0.1215
# Epoch  35 / iter   1, loss = 0.1410
# Epoch  35 / iter   2, loss = 0.1645
# Epoch  35 / iter   3, loss = 0.1232
# Epoch  36 / iter   0, loss = 0.1241
# Epoch  36 / iter   1, loss = 0.1245
# Epoch  36 / iter   2, loss = 0.1595
# Epoch  36 / iter   3, loss = 0.1300
# Epoch  37 / iter   0, loss = 0.1329
# Epoch  37 / iter   1, loss = 0.1277
# Epoch  37 / iter   2, loss = 0.1022
# Epoch  37 / iter   3, loss = 0.1630
# Epoch  38 / iter   0, loss = 0.1143
# Epoch  38 / iter   1, loss = 0.1270
# Epoch  38 / iter   2, loss = 0.1687
# Epoch  38 / iter   3, loss = 0.1032
# Epoch  39 / iter   0, loss = 0.1121
# Epoch  39 / iter   1, loss = 0.1717
# Epoch  39 / iter   2, loss = 0.1124
# Epoch  39 / iter   3, loss = 0.1056
# Epoch  40 / iter   0, loss = 0.0972
# Epoch  40 / iter   1, loss = 0.1581
# Epoch  40 / iter   2, loss = 0.1050
# Epoch  40 / iter   3, loss = 0.1306
# Epoch  41 / iter   0, loss = 0.1042
# Epoch  41 / iter   1, loss = 0.1070
# Epoch  41 / iter   2, loss = 0.1217
# Epoch  41 / iter   3, loss = 0.1482
# Epoch  42 / iter   0, loss = 0.1191
# Epoch  42 / iter   1, loss = 0.0837
# Epoch  42 / iter   2, loss = 0.1185
# Epoch  42 / iter   3, loss = 0.1494
# Epoch  43 / iter   0, loss = 0.1392
# Epoch  43 / iter   1, loss = 0.1166
# Epoch  43 / iter   2, loss = 0.1319
# Epoch  43 / iter   3, loss = 0.0732
# Epoch  44 / iter   0, loss = 0.1428
# Epoch  44 / iter   1, loss = 0.1319
# Epoch  44 / iter   2, loss = 0.0942
# Epoch  44 / iter   3, loss = 0.0828
# Epoch  45 / iter   0, loss = 0.1159
# Epoch  45 / iter   1, loss = 0.0905
# Epoch  45 / iter   2, loss = 0.1101
# Epoch  45 / iter   3, loss = 0.1264
# Epoch  46 / iter   0, loss = 0.1136
# Epoch  46 / iter   1, loss = 0.1360
# Epoch  46 / iter   2, loss = 0.0678
# Epoch  46 / iter   3, loss = 0.1170
# Epoch  47 / iter   0, loss = 0.1126
# Epoch  47 / iter   1, loss = 0.0988
# Epoch  47 / iter   2, loss = 0.1219
# Epoch  47 / iter   3, loss = 0.0926
# Epoch  48 / iter   0, loss = 0.0875
# Epoch  48 / iter   1, loss = 0.1318
# Epoch  48 / iter   2, loss = 0.0879
# Epoch  48 / iter   3, loss = 0.1109
# Epoch  49 / iter   0, loss = 0.1097
# Epoch  49 / iter   1, loss = 0.0831
# Epoch  49 / iter   2, loss = 0.0974
# Epoch  49 / iter   3, loss = 0.1201
# Epoch  50 / iter   0, loss = 0.1049
# Epoch  50 / iter   1, loss = 0.0817
# Epoch  50 / iter   2, loss = 0.1133
# Epoch  50 / iter   3, loss = 0.1032
# Epoch  51 / iter   0, loss = 0.0684
# Epoch  51 / iter   1, loss = 0.1028
# Epoch  51 / iter   2, loss = 0.1524
# Epoch  51 / iter   3, loss = 0.0721
# Epoch  52 / iter   0, loss = 0.0961
# Epoch  52 / iter   1, loss = 0.0911
# Epoch  52 / iter   2, loss = 0.0969
# Epoch  52 / iter   3, loss = 0.1050
# Epoch  53 / iter   0, loss = 0.0980
# Epoch  53 / iter   1, loss = 0.0792
# Epoch  53 / iter   2, loss = 0.0931
# Epoch  53 / iter   3, loss = 0.1121
# Epoch  54 / iter   0, loss = 0.0807
# Epoch  54 / iter   1, loss = 0.0818
# Epoch  54 / iter   2, loss = 0.1194
# Epoch  54 / iter   3, loss = 0.0940
# Epoch  55 / iter   0, loss = 0.0752
# Epoch  55 / iter   1, loss = 0.1078
# Epoch  55 / iter   2, loss = 0.0805
# Epoch  55 / iter   3, loss = 0.1063
# Epoch  56 / iter   0, loss = 0.1004
# Epoch  56 / iter   1, loss = 0.0764
# Epoch  56 / iter   2, loss = 0.0893
# Epoch  56 / iter   3, loss = 0.0975
# Epoch  57 / iter   0, loss = 0.1235
# Epoch  57 / iter   1, loss = 0.0656
# Epoch  57 / iter   2, loss = 0.0798
# Epoch  57 / iter   3, loss = 0.0889
# Epoch  58 / iter   0, loss = 0.1092
# Epoch  58 / iter   1, loss = 0.0901
# Epoch  58 / iter   2, loss = 0.0657
# Epoch  58 / iter   3, loss = 0.0870
# Epoch  59 / iter   0, loss = 0.0901
# Epoch  59 / iter   1, loss = 0.1022
# Epoch  59 / iter   2, loss = 0.0823
# Epoch  59 / iter   3, loss = 0.0721
# Epoch  60 / iter   0, loss = 0.0754
# Epoch  60 / iter   1, loss = 0.0593
# Epoch  60 / iter   2, loss = 0.0895
# Epoch  60 / iter   3, loss = 0.1168
# Epoch  61 / iter   0, loss = 0.1109
# Epoch  61 / iter   1, loss = 0.0835
# Epoch  61 / iter   2, loss = 0.0648
# Epoch  61 / iter   3, loss = 0.0768
# Epoch  62 / iter   0, loss = 0.1171
# Epoch  62 / iter   1, loss = 0.0863
# Epoch  62 / iter   2, loss = 0.0550
# Epoch  62 / iter   3, loss = 0.0727
# Epoch  63 / iter   0, loss = 0.0528
# Epoch  63 / iter   1, loss = 0.0919
# Epoch  63 / iter   2, loss = 0.0751
# Epoch  63 / iter   3, loss = 0.1066
# Epoch  64 / iter   0, loss = 0.1011
# Epoch  64 / iter   1, loss = 0.0796
# Epoch  64 / iter   2, loss = 0.0511
# Epoch  64 / iter   3, loss = 0.0894
# Epoch  65 / iter   0, loss = 0.1118
# Epoch  65 / iter   1, loss = 0.0691
# Epoch  65 / iter   2, loss = 0.0676
# Epoch  65 / iter   3, loss = 0.0685
# Epoch  66 / iter   0, loss = 0.0741
# Epoch  66 / iter   1, loss = 0.1062
# Epoch  66 / iter   2, loss = 0.0525
# Epoch  66 / iter   3, loss = 0.0796
# Epoch  67 / iter   0, loss = 0.0741
# Epoch  67 / iter   1, loss = 0.0961
# Epoch  67 / iter   2, loss = 0.0652
# Epoch  67 / iter   3, loss = 0.0728
# Epoch  68 / iter   0, loss = 0.0762
# Epoch  68 / iter   1, loss = 0.0734
# Epoch  68 / iter   2, loss = 0.1000
# Epoch  68 / iter   3, loss = 0.0544
# Epoch  69 / iter   0, loss = 0.0633
# Epoch  69 / iter   1, loss = 0.0484
# Epoch  69 / iter   2, loss = 0.0926
# Epoch  69 / iter   3, loss = 0.0959
# Epoch  70 / iter   0, loss = 0.0742
# Epoch  70 / iter   1, loss = 0.0748
# Epoch  70 / iter   2, loss = 0.0960
# Epoch  70 / iter   3, loss = 0.0509
# Epoch  71 / iter   0, loss = 0.0679
# Epoch  71 / iter   1, loss = 0.0918
# Epoch  71 / iter   2, loss = 0.0461
# Epoch  71 / iter   3, loss = 0.0862
# Epoch  72 / iter   0, loss = 0.0770
# Epoch  72 / iter   1, loss = 0.0866
# Epoch  72 / iter   2, loss = 0.0707
# Epoch  72 / iter   3, loss = 0.0540
# Epoch  73 / iter   0, loss = 0.0876
# Epoch  73 / iter   1, loss = 0.0593
# Epoch  73 / iter   2, loss = 0.0650
# Epoch  73 / iter   3, loss = 0.0728
# Epoch  74 / iter   0, loss = 0.0766
# Epoch  74 / iter   1, loss = 0.0788
# Epoch  74 / iter   2, loss = 0.0887
# Epoch  74 / iter   3, loss = 0.0369
# Epoch  75 / iter   0, loss = 0.1050
# Epoch  75 / iter   1, loss = 0.0613
# Epoch  75 / iter   2, loss = 0.0575
# Epoch  75 / iter   3, loss = 0.0538
# Epoch  76 / iter   0, loss = 0.0819
# Epoch  76 / iter   1, loss = 0.0586
# Epoch  76 / iter   2, loss = 0.0550
# Epoch  76 / iter   3, loss = 0.0790
# Epoch  77 / iter   0, loss = 0.0838
# Epoch  77 / iter   1, loss = 0.0825
# Epoch  77 / iter   2, loss = 0.0496
# Epoch  77 / iter   3, loss = 0.0549
# Epoch  78 / iter   0, loss = 0.0610
# Epoch  78 / iter   1, loss = 0.1043
# Epoch  78 / iter   2, loss = 0.0439
# Epoch  78 / iter   3, loss = 0.0590
# Epoch  79 / iter   0, loss = 0.0735
# Epoch  79 / iter   1, loss = 0.0481
# Epoch  79 / iter   2, loss = 0.0755
# Epoch  79 / iter   3, loss = 0.0677
# Epoch  80 / iter   0, loss = 0.0462
# Epoch  80 / iter   1, loss = 0.0377
# Epoch  80 / iter   2, loss = 0.1006
# Epoch  80 / iter   3, loss = 0.0770
# Epoch  81 / iter   0, loss = 0.0347
# Epoch  81 / iter   1, loss = 0.0735
# Epoch  81 / iter   2, loss = 0.0606
# Epoch  81 / iter   3, loss = 0.0899
# Epoch  82 / iter   0, loss = 0.0922
# Epoch  82 / iter   1, loss = 0.0668
# Epoch  82 / iter   2, loss = 0.0453
# Epoch  82 / iter   3, loss = 0.0510
# Epoch  83 / iter   0, loss = 0.0861
# Epoch  83 / iter   1, loss = 0.0487
# Epoch  83 / iter   2, loss = 0.0398
# Epoch  83 / iter   3, loss = 0.0782
# Epoch  84 / iter   0, loss = 0.0458
# Epoch  84 / iter   1, loss = 0.0510
# Epoch  84 / iter   2, loss = 0.0938
# Epoch  84 / iter   3, loss = 0.0592
# Epoch  85 / iter   0, loss = 0.0686
# Epoch  85 / iter   1, loss = 0.0612
# Epoch  85 / iter   2, loss = 0.0644
# Epoch  85 / iter   3, loss = 0.0533
# Epoch  86 / iter   0, loss = 0.0672
# Epoch  86 / iter   1, loss = 0.0562
# Epoch  86 / iter   2, loss = 0.0439
# Epoch  86 / iter   3, loss = 0.0774
# Epoch  87 / iter   0, loss = 0.0655
# Epoch  87 / iter   1, loss = 0.0655
# Epoch  87 / iter   2, loss = 0.0540
# Epoch  87 / iter   3, loss = 0.0574
# Epoch  88 / iter   0, loss = 0.0748
# Epoch  88 / iter   1, loss = 0.0645
# Epoch  88 / iter   2, loss = 0.0575
# Epoch  88 / iter   3, loss = 0.0427
# Epoch  89 / iter   0, loss = 0.0521
# Epoch  89 / iter   1, loss = 0.0647
# Epoch  89 / iter   2, loss = 0.0568
# Epoch  89 / iter   3, loss = 0.0640
# Epoch  90 / iter   0, loss = 0.0574
# Epoch  90 / iter   1, loss = 0.0523
# Epoch  90 / iter   2, loss = 0.0567
# Epoch  90 / iter   3, loss = 0.0684
# Epoch  91 / iter   0, loss = 0.0381
# Epoch  91 / iter   1, loss = 0.0658
# Epoch  91 / iter   2, loss = 0.0721
# Epoch  91 / iter   3, loss = 0.0568
# Epoch  92 / iter   0, loss = 0.0494
# Epoch  92 / iter   1, loss = 0.0670
# Epoch  92 / iter   2, loss = 0.0605
# Epoch  92 / iter   3, loss = 0.0535
# Epoch  93 / iter   0, loss = 0.0436
# Epoch  93 / iter   1, loss = 0.0525
# Epoch  93 / iter   2, loss = 0.0636
# Epoch  93 / iter   3, loss = 0.0682
# Epoch  94 / iter   0, loss = 0.0644
# Epoch  94 / iter   1, loss = 0.0575
# Epoch  94 / iter   2, loss = 0.0408
# Epoch  94 / iter   3, loss = 0.0629
# Epoch  95 / iter   0, loss = 0.0567
# Epoch  95 / iter   1, loss = 0.0766
# Epoch  95 / iter   2, loss = 0.0511
# Epoch  95 / iter   3, loss = 0.0389
# Epoch  96 / iter   0, loss = 0.0593
# Epoch  96 / iter   1, loss = 0.0574
# Epoch  96 / iter   2, loss = 0.0577
# Epoch  96 / iter   3, loss = 0.0470
# Epoch  97 / iter   0, loss = 0.0372
# Epoch  97 / iter   1, loss = 0.0662
# Epoch  97 / iter   2, loss = 0.0444
# Epoch  97 / iter   3, loss = 0.0714
# Epoch  98 / iter   0, loss = 0.0833
# Epoch  98 / iter   1, loss = 0.0608
# Epoch  98 / iter   2, loss = 0.0308
# Epoch  98 / iter   3, loss = 0.0424
# Epoch  99 / iter   0, loss = 0.0420
# Epoch  99 / iter   1, loss = 0.0835
# Epoch  99 / iter   2, loss = 0.0504
# Epoch  99 / iter   3, loss = 0.0395

# %%
# 画出损失函数的变化趋势
plot_x = np.arange(len(losses))
plot_y = np.array(losses)
plt.plot(plot_x, plot_y)
plt.show()

# %%
#####预测值与真实值的对比图：#####

# 获取测试集的预测值
x_test = test_data[:, :-1]
y_test = test_data[:, -1:]
predictions = net.forward(x_test)

# 绘制预测值与真实值的对比图
plt.scatter(range(len(y_test)), y_test, color='b', label='True Values')
plt.scatter(range(len(predictions)), predictions, color='r', label='Predictions')
plt.xlabel('Sample Index')
plt.ylabel('House Price')
plt.title('True Values vs Predictions')
plt.legend()
plt.show()

# %%
#####误差分布图：#####

# 计算预测值与真实值之间的误差
errors = predictions - y_test

# 绘制误差的直方图
plt.hist(errors, bins=20)
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Prediction Error Distribution')
plt.show()

# %%
#####学习曲线：#####

# 获取训练误差和验证误差
train_losses = losses[:len(losses)//2]  # 前一半为训练误差
val_losses = losses[len(losses)//2:]  # 后一半为验证误差

# 绘制学习曲线
plt.plot(range(len(train_losses)), train_losses, color='b', label='Train Loss')
plt.plot(range(len(val_losses)), val_losses, color='r', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Learning Curve')
plt.legend()
plt.show()

# %%
#####特征重要性可视化：#####

# 获取特征权重
feature_weights = np.abs(net.w.reshape(-1))  # 取绝对值以考虑权重的正负关系
feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',
                 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# 绘制特征重要性条形图
plt.barh(range(len(feature_weights)), feature_weights, tick_label=feature_names)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Feature Importance Bar Plot')
plt.show()

# %%
#####特征与房价的关系图：#####

for it__ in range(0,13):
    # 选择一个特征和目标变量进行可视化
    feature_index = it__  # 假设选择第一个特征 'CRIM'
    feature_name = feature_names[feature_index]
    x = train_data[:, feature_index]
    y = train_data[:, -1:]

    # 绘制特征与目标变量的散点图
    plt.scatter(x, y)
    plt.xlabel(feature_name)
    plt.ylabel('MEDV')
    plt.title(f'{feature_name} vs. MEDV')
    plt.show()

'''
# 选择一个特征和目标变量进行可视化
feature_index = 12  # 假设选择第一个特征 'CRIM'
feature_name = feature_names[feature_index]
x = train_data[:, feature_index]
y = train_data[:, -1:]

# 绘制特征与目标变量的散点图
plt.scatter(x, y)
plt.xlabel(feature_name)
plt.ylabel('MEDV')
plt.title(f'{feature_name} vs. MEDV')
plt.show()
'''
# Out:
# "\n# 选择一个特征和目标变量进行可视化\nfeature_index = 12  # 假设选择第一个特征 'CRIM'\nfeature_name = feature_names[feature_index]\nx = train_data[:, feature_index]\ny = train_data[:, -1:]\n\n# 绘制特征与目标变量的散点图\nplt.scatter(x, y)\nplt.xlabel(feature_name)\nplt.ylabel('MEDV')\nplt.title(f'{feature_name} vs. MEDV')\nplt.show()\n"

# %% [markdown]
# 5、保存模型：
# 将训练好的模型保存，以备预测时调用。

# %% [markdown]
# 结束。
