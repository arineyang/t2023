# %% [markdown]
# # 波士顿房价预测任务
#
# 波士顿房价预测是一个经典的机器学习任务，类似于程序员世界的“Hello World”。和大家对房价的普遍认知相同，波士顿地区的房价是由诸多因素影响的。该数据集统计了13种可能影响房价的因素和该类型房屋的均价，期望构建一个基于13个因素进行房价预测的模型，如 **图1** 所示。
# <br></br>
# <center><img src="https://ai-studio-static-online.cdn.bcebos.com/c19602ce74284e3b9a50422f8dc37c0c1c79cf5cd8424994b6a6b073dcb7c057" width="500" hegiht="" ></center>
# <center><br>图1：波士顿房价影响因素示意图</br></center>
# <br></br>
#
# 对于预测问题，可以根据预测输出的类型是连续的实数值，还是离散的标签，区分为回归任务和分类任务。因为房价是一个连续值，所以房价预测显然是一个回归任务。下面我们尝试用最简单的线性回归模型解决这个问题，并用神经网络来实现这个模型。
#
# ## 线性回归模型
#
# 假设房价和各影响因素之间能够用线性关系来描述：
#
# $$y = {\sum_{j=1}^Mx_j w_j} + b$$
#
# 模型的求解即是通过数据拟合出每个$w_j$和$b$。其中，$w_j$和$b$分别表示该线性模型的权重和偏置。一维情况下，$w_j$ 和 $b$ 是直线的斜率和截距。
#
# 线性回归模型使用均方误差作为损失函数（Loss），用以衡量预测房价和真实房价的差异，公式如下：
#
# $$MSE = \frac{1}{n} \sum_{i=1}^n(\hat{Y_i} - {Y_i})^{2}$$

# %% [markdown]
# 五个步骤：
# 1、数据处理：
# 从本地文件或网络地址读取数据，并做预处理操作，如校验数据的正确性等。
# 2、模型设计：
# 完成网络结构的设计（模型三要素之一），相当于模型的假设空间，即模型能够表达的关系集合。
# 3、训练配置：
# 设定模型采用的寻解算法（模型三要素之二），即优化器，并指定计算资源。
# 4、训练过程：
# 循环调用训练过程，每轮均包括前向计算、损失函数（优化目标，模型三要素之三）和后向传播这三个步骤。
# 5、保存模型：
# 将训练好的模型保存，以备预测时调用。

# %% [markdown]
# 1、数据处理：
# 从本地文件或网络地址读取数据，并做预处理操作，如校验数据的正确性等。

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def load_data():
    # 从文件导入数据
    datafile = './work/housing.data'
    data = np.fromfile(datafile, sep=' ')

    # 每条数据包括14项，其中前面13项是影响因素，第14项是相应的房屋价格中位数
    feature_names = [ 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', \
                      'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV' ]
    feature_num = len(feature_names)

    # 将原始数据进行Reshape，变成[N, 14]这样的形状
    data = data.reshape([data.shape[0] // feature_num, feature_num])

    # 将原数据集拆分成训练集和测试集
    # 这里使用80%的数据做训练，20%的数据做测试
    # 测试集和训练集必须是没有交集的
    ratio = 0.8
    offset = int(data.shape[0] * ratio)
    training_data = data[:offset]

    # 计算train数据集的最大值，最小值，平均值
    maximums, minimums, avgs = training_data.max(axis=0), training_data.min(axis=0), \
                                 training_data.sum(axis=0) / training_data.shape[0]

    # 对数据进行归一化处理
    for i in range(feature_num):
        #print(maximums[i], minimums[i], avgs[i])
        data[:, i] = (data[:, i] - avgs[i]) / (maximums[i] - minimums[i])

    # 训练集和测试集的划分比例
    training_data = data[:offset]
    test_data = data[offset:]
    return training_data, test_data

# end load_data

# %% [markdown]
# 2、模型设计：
# 完成网络结构的设计（模型三要素之一），相当于模型的假设空间，即模型能够表达的关系集合。
#
# 3、训练配置：
# 设定模型采用的寻解算法（模型三要素之二），即优化器，并指定计算资源。
#
# 4、训练过程：
# 循环调用训练过程，每轮均包括前向计算、损失函数（优化目标，模型三要素之三）和后向传播这三个步骤。

# %%
class Network(object):
    def __init__(self, num_of_weights):
        # 随机产生w的初始值
        # 为了保持程序每次运行结果的一致性，此处设置固定的随机数种子
        np.random.seed(0)
        self.w = np.random.randn(num_of_weights, 1)
        self.b = 0.
        
    def forward(self, x):
        z = np.dot(x, self.w) + self.b
        zz = self.relu(z)  # 使用ReLU作为激活函数
        return zz
    
    def loss(self, z, y):
        error = z - y
        num_samples = error.shape[0]
        cost = error * error
        cost = np.sum(cost) / num_samples
        return cost
    
    def gradient(self, x, y):
        z = self.forward(x)
        N = x.shape[0]
        gradient_w = 1. / N * np.sum((z-y) * x, axis=0)
        gradient_w = gradient_w[:, np.newaxis]
        gradient_b = 1. / N * np.sum(z-y)
        return gradient_w, gradient_b
    
    def update(self, gradient_w, gradient_b, eta = 0.01):
        self.w = self.w - eta * gradient_w
        self.b = self.b - eta * gradient_b
            
                
    def train(self, training_data, num_epoches, batch_size=10, eta=0.01):
        n = len(training_data)
        losses = []
        for epoch_id in range(num_epoches):
            # 在每轮迭代开始之前，将训练数据的顺序随机的打乱，
            # 然后再按每次取batch_size条数据的方式取出
            np.random.shuffle(training_data)
            # 将训练数据进行拆分，每个mini_batch包含batch_size条的数据
            mini_batches = [training_data[k:k+batch_size] for k in range(0, n, batch_size)]
            for iter_id, mini_batch in enumerate(mini_batches):
                #print(self.w.shape)
                #print(self.b)
                x = mini_batch[:, :-1]
                y = mini_batch[:, -1:]
                a = self.forward(x)
                loss = self.loss(a, y)
                gradient_w, gradient_b = self.gradient(x, y)
                self.update(gradient_w, gradient_b, eta)
                losses.append(loss)
                print('Epoch {:3d} / iter {:3d}, loss = {:.4f}'.
                                 format(epoch_id, iter_id, loss))
        
        return losses

    def relu(self, x):
        return np.maximum(0, x)

    def leaky_relu(self, x, alpha=0.01):
        return np.where(x >= 0, x, alpha * x)

    def sigmoid(self, x):
        return 1 / (1 + np.exp(-x))
    
# end class

# %%
# 获取数据
train_data, test_data = load_data()

# 创建网络
net = Network(13)
# 启动训练
losses = net.train(train_data, num_epoches=100, batch_size=101, eta=0.1)
# Out:
# Epoch   0 / iter   0, loss = 1.8092
# Epoch   0 / iter   1, loss = 0.9164
# Epoch   0 / iter   2, loss = 0.8236
# Epoch   0 / iter   3, loss = 1.1136
# Epoch   1 / iter   0, loss = 1.2355
# Epoch   1 / iter   1, loss = 0.9903
# Epoch   1 / iter   2, loss = 0.5585
# Epoch   1 / iter   3, loss = 0.6573
# Epoch   2 / iter   0, loss = 0.5283
# Epoch   2 / iter   1, loss = 0.6280
# Epoch   2 / iter   2, loss = 0.7087
# Epoch   2 / iter   3, loss = 0.7418
# Epoch   3 / iter   0, loss = 0.3332
# Epoch   3 / iter   1, loss = 0.7598
# Epoch   3 / iter   2, loss = 0.4007
# Epoch   3 / iter   3, loss = 0.5273
# Epoch   4 / iter   0, loss = 0.6456
# Epoch   4 / iter   1, loss = 0.3630
# Epoch   4 / iter   2, loss = 0.2843
# Epoch   4 / iter   3, loss = 0.3115
# Epoch   5 / iter   0, loss = 0.5851
# Epoch   5 / iter   1, loss = 0.3028
# Epoch   5 / iter   2, loss = 0.2996
# Epoch   5 / iter   3, loss = 0.1236
# Epoch   6 / iter   0, loss = 0.2403
# Epoch   6 / iter   1, loss = 0.2648
# Epoch   6 / iter   2, loss = 0.2502
# Epoch   6 / iter   3, loss = 0.3308
# Epoch   7 / iter   0, loss = 0.2590
# Epoch   7 / iter   1, loss = 0.1637
# Epoch   7 / iter   2, loss = 0.3588
# Epoch   7 / iter   3, loss = 0.1432
# Epoch   8 / iter   0, loss = 0.2592
# Epoch   8 / iter   1, loss = 0.1371
# Epoch   8 / iter   2, loss = 0.3322
# Epoch   8 / iter   3, loss = 0.0770
# Epoch   9 / iter   0, loss = 0.2346
# Epoch   9 / iter   1, loss = 0.1341
# Epoch   9 / iter   2, loss = 0.1313
# Epoch   9 / iter   3, loss = 0.2053
# Epoch  10 / iter   0, loss = 0.2399
# Epoch  10 / iter   1, loss = 0.0642
# Epoch  10 / iter   2, loss = 0.1584
# Epoch  10 / iter   3, loss = 0.1681
# Epoch  11 / iter   0, loss = 0.1488
# Epoch  11 / iter   1, loss = 0.1580
# Epoch  11 / iter   2, loss = 0.0870
# Epoch  11 / iter   3, loss = 0.1728
# Epoch  12 / iter   0, loss = 0.1267
# Epoch  12 / iter   1, loss = 0.1100
# Epoch  12 / iter   2, loss = 0.0669
# Epoch  12 / iter   3, loss = 0.2104
# Epoch  13 / iter   0, loss = 0.1569
# Epoch  13 / iter   1, loss = 0.0545
# Epoch  13 / iter   2, loss = 0.1823
# Epoch  13 / iter   3, loss = 0.0802
# Epoch  14 / iter   0, loss = 0.0979
# Epoch  14 / iter   1, loss = 0.1434
# Epoch  14 / iter   2, loss = 0.0926
# Epoch  14 / iter   3, loss = 0.1034
# Epoch  15 / iter   0, loss = 0.0626
# Epoch  15 / iter   1, loss = 0.1711
# Epoch  15 / iter   2, loss = 0.1132
# Epoch  15 / iter   3, loss = 0.0591
# Epoch  16 / iter   0, loss = 0.0880
# Epoch  16 / iter   1, loss = 0.0976
# Epoch  16 / iter   2, loss = 0.0929
# Epoch  16 / iter   3, loss = 0.1038
# Epoch  17 / iter   0, loss = 0.1209
# Epoch  17 / iter   1, loss = 0.0976
# Epoch  17 / iter   2, loss = 0.0706
# Epoch  17 / iter   3, loss = 0.0714
# Epoch  18 / iter   0, loss = 0.0521
# Epoch  18 / iter   1, loss = 0.0814
# Epoch  18 / iter   2, loss = 0.0483
# Epoch  18 / iter   3, loss = 0.1602
# Epoch  19 / iter   0, loss = 0.0445
# Epoch  19 / iter   1, loss = 0.1252
# Epoch  19 / iter   2, loss = 0.0544
# Epoch  19 / iter   3, loss = 0.1017
# Epoch  20 / iter   0, loss = 0.0547
# Epoch  20 / iter   1, loss = 0.0825
# Epoch  20 / iter   2, loss = 0.0678
# Epoch  20 / iter   3, loss = 0.1067
# Epoch  21 / iter   0, loss = 0.1189
# Epoch  21 / iter   1, loss = 0.0710
# Epoch  21 / iter   2, loss = 0.0575
# Epoch  21 / iter   3, loss = 0.0530
# Epoch  22 / iter   0, loss = 0.0851
# Epoch  22 / iter   1, loss = 0.0588
# Epoch  22 / iter   2, loss = 0.0597
# Epoch  22 / iter   3, loss = 0.0855
# Epoch  23 / iter   0, loss = 0.0428
# Epoch  23 / iter   1, loss = 0.1008
# Epoch  23 / iter   2, loss = 0.0945
# Epoch  23 / iter   3, loss = 0.0420
# Epoch  24 / iter   0, loss = 0.0781
# Epoch  24 / iter   1, loss = 0.0413
# Epoch  24 / iter   2, loss = 0.0799
# Epoch  24 / iter   3, loss = 0.0721
# Epoch  25 / iter   0, loss = 0.0508
# Epoch  25 / iter   1, loss = 0.1053
# Epoch  25 / iter   2, loss = 0.0473
# Epoch  25 / iter   3, loss = 0.0613
# Epoch  26 / iter   0, loss = 0.0919
# Epoch  26 / iter   1, loss = 0.0423
# Epoch  26 / iter   2, loss = 0.0750
# Epoch  26 / iter   3, loss = 0.0493
# Epoch  27 / iter   0, loss = 0.0855
# Epoch  27 / iter   1, loss = 0.0528
# Epoch  27 / iter   2, loss = 0.0666
# Epoch  27 / iter   3, loss = 0.0470
# Epoch  28 / iter   0, loss = 0.0394
# Epoch  28 / iter   1, loss = 0.0480
# Epoch  28 / iter   2, loss = 0.0984
# Epoch  28 / iter   3, loss = 0.0603
# Epoch  29 / iter   0, loss = 0.0647
# Epoch  29 / iter   1, loss = 0.0577
# Epoch  29 / iter   2, loss = 0.0409
# Epoch  29 / iter   3, loss = 0.0772
# Epoch  30 / iter   0, loss = 0.0483
# Epoch  30 / iter   1, loss = 0.0488
# Epoch  30 / iter   2, loss = 0.0792
# Epoch  30 / iter   3, loss = 0.0593
# Epoch  31 / iter   0, loss = 0.0658
# Epoch  31 / iter   1, loss = 0.0562
# Epoch  31 / iter   2, loss = 0.0446
# Epoch  31 / iter   3, loss = 0.0649
# Epoch  32 / iter   0, loss = 0.0561
# Epoch  32 / iter   1, loss = 0.0930
# Epoch  32 / iter   2, loss = 0.0347
# Epoch  32 / iter   3, loss = 0.0443
# Epoch  33 / iter   0, loss = 0.0615
# Epoch  33 / iter   1, loss = 0.0363
# Epoch  33 / iter   2, loss = 0.0548
# Epoch  33 / iter   3, loss = 0.0710
# Epoch  34 / iter   0, loss = 0.0516
# Epoch  34 / iter   1, loss = 0.0383
# Epoch  34 / iter   2, loss = 0.0517
# Epoch  34 / iter   3, loss = 0.0784
# Epoch  35 / iter   0, loss = 0.0615
# Epoch  35 / iter   1, loss = 0.0552
# Epoch  35 / iter   2, loss = 0.0542
# Epoch  35 / iter   3, loss = 0.0463
# Epoch  36 / iter   0, loss = 0.0471
# Epoch  36 / iter   1, loss = 0.0527
# Epoch  36 / iter   2, loss = 0.0676
# Epoch  36 / iter   3, loss = 0.0469
# Epoch  37 / iter   0, loss = 0.0504
# Epoch  37 / iter   1, loss = 0.0508
# Epoch  37 / iter   2, loss = 0.0356
# Epoch  37 / iter   3, loss = 0.0747
# Epoch  38 / iter   0, loss = 0.0586
# Epoch  38 / iter   1, loss = 0.0574
# Epoch  38 / iter   2, loss = 0.0601
# Epoch  38 / iter   3, loss = 0.0333
# Epoch  39 / iter   0, loss = 0.0563
# Epoch  39 / iter   1, loss = 0.0616
# Epoch  39 / iter   2, loss = 0.0546
# Epoch  39 / iter   3, loss = 0.0344
# Epoch  40 / iter   0, loss = 0.0295
# Epoch  40 / iter   1, loss = 0.0902
# Epoch  40 / iter   2, loss = 0.0313
# Epoch  40 / iter   3, loss = 0.0536
# Epoch  41 / iter   0, loss = 0.0470
# Epoch  41 / iter   1, loss = 0.0483
# Epoch  41 / iter   2, loss = 0.0398
# Epoch  41 / iter   3, loss = 0.0678
# Epoch  42 / iter   0, loss = 0.0498
# Epoch  42 / iter   1, loss = 0.0350
# Epoch  42 / iter   2, loss = 0.0522
# Epoch  42 / iter   3, loss = 0.0639
# Epoch  43 / iter   0, loss = 0.0601
# Epoch  43 / iter   1, loss = 0.0576
# Epoch  43 / iter   2, loss = 0.0485
# Epoch  43 / iter   3, loss = 0.0334
# Epoch  44 / iter   0, loss = 0.0713
# Epoch  44 / iter   1, loss = 0.0424
# Epoch  44 / iter   2, loss = 0.0346
# Epoch  44 / iter   3, loss = 0.0499
# Epoch  45 / iter   0, loss = 0.0465
# Epoch  45 / iter   1, loss = 0.0453
# Epoch  45 / iter   2, loss = 0.0438
# Epoch  45 / iter   3, loss = 0.0605
# Epoch  46 / iter   0, loss = 0.0536
# Epoch  46 / iter   1, loss = 0.0511
# Epoch  46 / iter   2, loss = 0.0390
# Epoch  46 / iter   3, loss = 0.0513
# Epoch  47 / iter   0, loss = 0.0461
# Epoch  47 / iter   1, loss = 0.0373
# Epoch  47 / iter   2, loss = 0.0585
# Epoch  47 / iter   3, loss = 0.0517
# Epoch  48 / iter   0, loss = 0.0321
# Epoch  48 / iter   1, loss = 0.0616
# Epoch  48 / iter   2, loss = 0.0413
# Epoch  48 / iter   3, loss = 0.0573
# Epoch  49 / iter   0, loss = 0.0583
# Epoch  49 / iter   1, loss = 0.0317
# Epoch  49 / iter   2, loss = 0.0518
# Epoch  49 / iter   3, loss = 0.0496
# Epoch  50 / iter   0, loss = 0.0458
# Epoch  50 / iter   1, loss = 0.0395
# Epoch  50 / iter   2, loss = 0.0508
# Epoch  50 / iter   3, loss = 0.0540
# Epoch  51 / iter   0, loss = 0.0364
# Epoch  51 / iter   1, loss = 0.0526
# Epoch  51 / iter   2, loss = 0.0672
# Epoch  51 / iter   3, loss = 0.0327
# Epoch  52 / iter   0, loss = 0.0436
# Epoch  52 / iter   1, loss = 0.0388
# Epoch  52 / iter   2, loss = 0.0472
# Epoch  52 / iter   3, loss = 0.0582
# Epoch  53 / iter   0, loss = 0.0395
# Epoch  53 / iter   1, loss = 0.0473
# Epoch  53 / iter   2, loss = 0.0452
# Epoch  53 / iter   3, loss = 0.0549
# Epoch  54 / iter   0, loss = 0.0446
# Epoch  54 / iter   1, loss = 0.0491
# Epoch  54 / iter   2, loss = 0.0561
# Epoch  54 / iter   3, loss = 0.0363
# Epoch  55 / iter   0, loss = 0.0335
# Epoch  55 / iter   1, loss = 0.0558
# Epoch  55 / iter   2, loss = 0.0541
# Epoch  55 / iter   3, loss = 0.0417
# Epoch  56 / iter   0, loss = 0.0547
# Epoch  56 / iter   1, loss = 0.0257
# Epoch  56 / iter   2, loss = 0.0480
# Epoch  56 / iter   3, loss = 0.0557
# Epoch  57 / iter   0, loss = 0.0614
# Epoch  57 / iter   1, loss = 0.0423
# Epoch  57 / iter   2, loss = 0.0413
# Epoch  57 / iter   3, loss = 0.0386
# Epoch  58 / iter   0, loss = 0.0414
# Epoch  58 / iter   1, loss = 0.0504
# Epoch  58 / iter   2, loss = 0.0497
# Epoch  58 / iter   3, loss = 0.0413
# Epoch  59 / iter   0, loss = 0.0453
# Epoch  59 / iter   1, loss = 0.0544
# Epoch  59 / iter   2, loss = 0.0487
# Epoch  59 / iter   3, loss = 0.0335
# Epoch  60 / iter   0, loss = 0.0378
# Epoch  60 / iter   1, loss = 0.0493
# Epoch  60 / iter   2, loss = 0.0330
# Epoch  60 / iter   3, loss = 0.0613
# Epoch  61 / iter   0, loss = 0.0447
# Epoch  61 / iter   1, loss = 0.0452
# Epoch  61 / iter   2, loss = 0.0438
# Epoch  61 / iter   3, loss = 0.0469
# Epoch  62 / iter   0, loss = 0.0534
# Epoch  62 / iter   1, loss = 0.0415
# Epoch  62 / iter   2, loss = 0.0338
# Epoch  62 / iter   3, loss = 0.0512
# Epoch  63 / iter   0, loss = 0.0396
# Epoch  63 / iter   1, loss = 0.0643
# Epoch  63 / iter   2, loss = 0.0284
# Epoch  63 / iter   3, loss = 0.0470
# Epoch  64 / iter   0, loss = 0.0454
# Epoch  64 / iter   1, loss = 0.0408
# Epoch  64 / iter   2, loss = 0.0416
# Epoch  64 / iter   3, loss = 0.0509
# Epoch  65 / iter   0, loss = 0.0610
# Epoch  65 / iter   1, loss = 0.0384
# Epoch  65 / iter   2, loss = 0.0435
# Epoch  65 / iter   3, loss = 0.0353
# Epoch  66 / iter   0, loss = 0.0502
# Epoch  66 / iter   1, loss = 0.0432
# Epoch  66 / iter   2, loss = 0.0381
# Epoch  66 / iter   3, loss = 0.0461
# Epoch  67 / iter   0, loss = 0.0430
# Epoch  67 / iter   1, loss = 0.0528
# Epoch  67 / iter   2, loss = 0.0458
# Epoch  67 / iter   3, loss = 0.0356
# Epoch  68 / iter   0, loss = 0.0420
# Epoch  68 / iter   1, loss = 0.0408
# Epoch  68 / iter   2, loss = 0.0510
# Epoch  68 / iter   3, loss = 0.0430
# Epoch  69 / iter   0, loss = 0.0409
# Epoch  69 / iter   1, loss = 0.0376
# Epoch  69 / iter   2, loss = 0.0548
# Epoch  69 / iter   3, loss = 0.0429
# Epoch  70 / iter   0, loss = 0.0472
# Epoch  70 / iter   1, loss = 0.0298
# Epoch  70 / iter   2, loss = 0.0594
# Epoch  70 / iter   3, loss = 0.0393
# Epoch  71 / iter   0, loss = 0.0412
# Epoch  71 / iter   1, loss = 0.0464
# Epoch  71 / iter   2, loss = 0.0479
# Epoch  71 / iter   3, loss = 0.0397
# Epoch  72 / iter   0, loss = 0.0415
# Epoch  72 / iter   1, loss = 0.0490
# Epoch  72 / iter   2, loss = 0.0439
# Epoch  72 / iter   3, loss = 0.0406
# Epoch  73 / iter   0, loss = 0.0466
# Epoch  73 / iter   1, loss = 0.0361
# Epoch  73 / iter   2, loss = 0.0559
# Epoch  73 / iter   3, loss = 0.0361
# Epoch  74 / iter   0, loss = 0.0576
# Epoch  74 / iter   1, loss = 0.0412
# Epoch  74 / iter   2, loss = 0.0407
# Epoch  74 / iter   3, loss = 0.0349
# Epoch  75 / iter   0, loss = 0.0423
# Epoch  75 / iter   1, loss = 0.0438
# Epoch  75 / iter   2, loss = 0.0471
# Epoch  75 / iter   3, loss = 0.0408
# Epoch  76 / iter   0, loss = 0.0401
# Epoch  76 / iter   1, loss = 0.0498
# Epoch  76 / iter   2, loss = 0.0481
# Epoch  76 / iter   3, loss = 0.0359
# Epoch  77 / iter   0, loss = 0.0524
# Epoch  77 / iter   1, loss = 0.0329
# Epoch  77 / iter   2, loss = 0.0435
# Epoch  77 / iter   3, loss = 0.0445
# Epoch  78 / iter   0, loss = 0.0392
# Epoch  78 / iter   1, loss = 0.0441
# Epoch  78 / iter   2, loss = 0.0407
# Epoch  78 / iter   3, loss = 0.0490
# Epoch  79 / iter   0, loss = 0.0380
# Epoch  79 / iter   1, loss = 0.0413
# Epoch  79 / iter   2, loss = 0.0418
# Epoch  79 / iter   3, loss = 0.0522
# Epoch  80 / iter   0, loss = 0.0447
# Epoch  80 / iter   1, loss = 0.0361
# Epoch  80 / iter   2, loss = 0.0355
# Epoch  80 / iter   3, loss = 0.0565
# Epoch  81 / iter   0, loss = 0.0265
# Epoch  81 / iter   1, loss = 0.0551
# Epoch  81 / iter   2, loss = 0.0436
# Epoch  81 / iter   3, loss = 0.0479
# Epoch  82 / iter   0, loss = 0.0491
# Epoch  82 / iter   1, loss = 0.0382
# Epoch  82 / iter   2, loss = 0.0484
# Epoch  82 / iter   3, loss = 0.0372
# Epoch  83 / iter   0, loss = 0.0459
# Epoch  83 / iter   1, loss = 0.0440
# Epoch  83 / iter   2, loss = 0.0387
# Epoch  83 / iter   3, loss = 0.0441
# Epoch  84 / iter   0, loss = 0.0368
# Epoch  84 / iter   1, loss = 0.0474
# Epoch  84 / iter   2, loss = 0.0399
# Epoch  84 / iter   3, loss = 0.0487
# Epoch  85 / iter   0, loss = 0.0570
# Epoch  85 / iter   1, loss = 0.0400
# Epoch  85 / iter   2, loss = 0.0369
# Epoch  85 / iter   3, loss = 0.0387
# Epoch  86 / iter   0, loss = 0.0472
# Epoch  86 / iter   1, loss = 0.0412
# Epoch  86 / iter   2, loss = 0.0467
# Epoch  86 / iter   3, loss = 0.0376
# Epoch  87 / iter   0, loss = 0.0424
# Epoch  87 / iter   1, loss = 0.0495
# Epoch  87 / iter   2, loss = 0.0440
# Epoch  87 / iter   3, loss = 0.0370
# Epoch  88 / iter   0, loss = 0.0387
# Epoch  88 / iter   1, loss = 0.0502
# Epoch  88 / iter   2, loss = 0.0392
# Epoch  88 / iter   3, loss = 0.0448
# Epoch  89 / iter   0, loss = 0.0401
# Epoch  89 / iter   1, loss = 0.0512
# Epoch  89 / iter   2, loss = 0.0486
# Epoch  89 / iter   3, loss = 0.0330
# Epoch  90 / iter   0, loss = 0.0437
# Epoch  90 / iter   1, loss = 0.0374
# Epoch  90 / iter   2, loss = 0.0425
# Epoch  90 / iter   3, loss = 0.0496
# Epoch  91 / iter   0, loss = 0.0390
# Epoch  91 / iter   1, loss = 0.0479
# Epoch  91 / iter   2, loss = 0.0377
# Epoch  91 / iter   3, loss = 0.0484
# Epoch  92 / iter   0, loss = 0.0453
# Epoch  92 / iter   1, loss = 0.0393
# Epoch  92 / iter   2, loss = 0.0449
# Epoch  92 / iter   3, loss = 0.0442
# Epoch  93 / iter   0, loss = 0.0327
# Epoch  93 / iter   1, loss = 0.0471
# Epoch  93 / iter   2, loss = 0.0544
# Epoch  93 / iter   3, loss = 0.0394
# Epoch  94 / iter   0, loss = 0.0374
# Epoch  94 / iter   1, loss = 0.0487
# Epoch  94 / iter   2, loss = 0.0456
# Epoch  94 / iter   3, loss = 0.0422
# Epoch  95 / iter   0, loss = 0.0367
# Epoch  95 / iter   1, loss = 0.0412
# Epoch  95 / iter   2, loss = 0.0593
# Epoch  95 / iter   3, loss = 0.0368
# Epoch  96 / iter   0, loss = 0.0538
# Epoch  96 / iter   1, loss = 0.0403
# Epoch  96 / iter   2, loss = 0.0507
# Epoch  96 / iter   3, loss = 0.0293
# Epoch  97 / iter   0, loss = 0.0328
# Epoch  97 / iter   1, loss = 0.0444
# Epoch  97 / iter   2, loss = 0.0483
# Epoch  97 / iter   3, loss = 0.0490
# Epoch  98 / iter   0, loss = 0.0382
# Epoch  98 / iter   1, loss = 0.0449
# Epoch  98 / iter   2, loss = 0.0493
# Epoch  98 / iter   3, loss = 0.0427
# Epoch  99 / iter   0, loss = 0.0491
# Epoch  99 / iter   1, loss = 0.0483
# Epoch  99 / iter   2, loss = 0.0467
# Epoch  99 / iter   3, loss = 0.0309

# %%
# 画出损失函数的变化趋势
plot_x = np.arange(len(losses))
plot_y = np.array(losses)
plt.plot(plot_x, plot_y)
plt.show()

# %%
#####预测值与真实值的对比图：#####

# 获取测试集的预测值
x_test = test_data[:, :-1]
y_test = test_data[:, -1:]
predictions = net.forward(x_test)

# 绘制预测值与真实值的对比图
plt.scatter(range(len(y_test)), y_test, color='b', label='True Values')
plt.scatter(range(len(predictions)), predictions, color='r', label='Predictions')
plt.xlabel('Sample Index')
plt.ylabel('House Price')
plt.title('True Values vs Predictions')
plt.legend()
plt.show()

# %%
#####误差分布图：#####

# 计算预测值与真实值之间的误差
errors = predictions - y_test

# 绘制误差的直方图
plt.hist(errors, bins=20)
plt.xlabel('Prediction Error')
plt.ylabel('Frequency')
plt.title('Prediction Error Distribution')
plt.show()

# %%
#####学习曲线：#####

# 获取训练误差和验证误差
train_losses = losses[:len(losses)//2]  # 前一半为训练误差
val_losses = losses[len(losses)//2:]  # 后一半为验证误差

# 绘制学习曲线
plt.plot(range(len(train_losses)), train_losses, color='b', label='Train Loss')
plt.plot(range(len(val_losses)), val_losses, color='r', label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Learning Curve')
plt.legend()
plt.show()

# %%
#####特征重要性可视化：#####

# 获取特征权重
feature_weights = np.abs(net.w.reshape(-1))  # 取绝对值以考虑权重的正负关系
feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',
                 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# 绘制特征重要性条形图
plt.barh(range(len(feature_weights)), feature_weights, tick_label=feature_names)
plt.xlabel('Feature Importance')
plt.ylabel('Features')
plt.title('Feature Importance Bar Plot')
plt.show()

# %%
#####特征与房价的关系图：#####

for it__ in range(0,13):
    # 选择一个特征和目标变量进行可视化
    feature_index = it__  # 假设选择第一个特征 'CRIM'
    feature_name = feature_names[feature_index]
    x = train_data[:, feature_index]
    y = train_data[:, -1:]

    # 绘制特征与目标变量的散点图
    plt.scatter(x, y)
    plt.xlabel(feature_name)
    plt.ylabel('MEDV')
    plt.title(f'{feature_name} vs. MEDV')
    plt.show()

'''
# 选择一个特征和目标变量进行可视化
feature_index = 12  # 假设选择第一个特征 'CRIM'
feature_name = feature_names[feature_index]
x = train_data[:, feature_index]
y = train_data[:, -1:]

# 绘制特征与目标变量的散点图
plt.scatter(x, y)
plt.xlabel(feature_name)
plt.ylabel('MEDV')
plt.title(f'{feature_name} vs. MEDV')
plt.show()
'''
# Out:
# "\n# 选择一个特征和目标变量进行可视化\nfeature_index = 12  # 假设选择第一个特征 'CRIM'\nfeature_name = feature_names[feature_index]\nx = train_data[:, feature_index]\ny = train_data[:, -1:]\n\n# 绘制特征与目标变量的散点图\nplt.scatter(x, y)\nplt.xlabel(feature_name)\nplt.ylabel('MEDV')\nplt.title(f'{feature_name} vs. MEDV')\nplt.show()\n"

# %% [markdown]
# 5、保存模型：
# 将训练好的模型保存，以备预测时调用。

# %% [markdown]
# 结束。
